# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhavi-1234/pytorch-from-scratch/blob/main/Pytorch_autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dy_dx(x):
  return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %%
import math

def dz_dx(x):
  return 2*x*math.cos(x**2)

# %%
dz_dx(2)
# Out:
# -2.6145744834544478

# %%
import torch

# %%
x= torch.tensor(3.0, requires_grad=True)

# %%
y= x**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2667620414.py in <cell line: 0>()
# ----> 1 y= x**2
#
# NameError: name 'x' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-32546335.py in <cell line: 0>()
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
x= torch.tensor(3.0, requires_grad= True)

# %%
y= x**2

# %%
z= torch.sin(y)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %%
import torch

x= torch.tensor(6.7)  # Input feature
y= torch.tensor(0.0)  # True label (binary)

w= torch.tensor(1.0)  # weight
b= torch.tensor(0.0)  # Bias

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon= 1e-8  # To prevent log(0)

    prediction= torch.clamp(prediction, epsilon, 1- epsilon)
    return -(target * torch.log(prediction) +(1- target) * torch.log(1- prediction))

# %%
# Forward Pass
z= w * x + b                # Weighted sum ( linear part)
y_pred= torch.sigmoid(z)    # predicted probability

# Compute binary cross- entropy loss
loss= binary_cross_entropy_loss(y_pred, y)

# %%
# Derivates:

# 1. dL/d(y_pred): loss with respect to the prediction (y_pred)
dloss_dy_pred= (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz= y_pred * (1- y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw= x  # dz/dw=x
dz_db=1   # dz.db=1 ( bias contributes directly to z)

dL_dw= dloss_dy_pred * dy_pred_dz * dz_dw
dL_db= dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"manual Gradient of loss w.r.t bias(db):{dL_db}")
# Out:
# manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# manual Gradient of loss w.r.t bias(db):0.998770534992218

# %%
x= torch.tensor(6.7)
y= torch.tensor(0.0)

# %%
w= torch.tensor(1.0,requires_grad= True)
b= torch.tensor(0.0, requires_grad= True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z= w * x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred= torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988)

# %%
loss= binary_cross_entropy_loss(y_pred,y)
loss
# Out:
# tensor(6.7012)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
x= torch.tensor([1.0,2.0,3.0], requires_grad= True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y= (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
#  clearing grad
x= torch.tensor(2.0, requires_grad= True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y= x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# disable gradient tracking

x= torch.tensor(2.0, requires_grad= True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y= x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
# option 1- requires_grad_(False)
x.requires_grad_(False)
x
# Out:
# tensor(2.)

# %%
y= x**2
y
# Out:
# tensor(4.)

# %%
# so will not work
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3856565394.py in <cell line: 0>()
#       1 # so will not work
# ----> 2 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
# ...

# %%
#  option 1  detach()
x= torch.tensor(2.0, requires_grad= True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z= x.detach()
z
# Out:
# tensor(2.)

# %%
y= x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
y1= z **2

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3844781142.py in <cell line: 0>()
# ----> 1 y1.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...

# %%
# option 3   torch.no_grad()
x= torch.tensor (2.0, requires_grad= True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
with torch.no_grad():
  y= x**2
  y

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1055444503.py in <cell line: 0>()
# ----> 1 y.backward()
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# ...
